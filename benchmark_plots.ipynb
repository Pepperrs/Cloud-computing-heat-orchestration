# %% [markdown]
# # Diskbenchmarks

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv(
    'results.csv', sep=';', header=-1, parse_dates=['time'],
    names=['time', 'daytime', 'scenario', 'seconds'])

# %%
server_list = df[df['scenario'] == 'server list']

# %%
sns.barplot(x="daytime", y="seconds", hue="scenario", data=server_list)

# %%
server_creation = df[df['scenario'] == 'server creation']

# %%
sns.barplot(x="daytime", y="seconds", hue="scenario", data=server_creation)
